# %%
# !pytest -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-8.4.2, pluggy-1.6.0 -- c:\Users\odigv\Desktop\ithub\3\testing\kt3\.venv\Scripts\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\odigv\Desktop\ithub\3\testing\kt3
# plugins: anyio-4.11.0, sugar-1.1.1
# collecting ... collected 16 items
#
# tests/test_math.py::test_is_even[2-True] PASSED                          [  6%]
# tests/test_math.py::test_is_even[3-False] PASSED                         [ 12%]
# tests/test_math.py::test_is_even[0-True] PASSED                          [ 18%]
# tests/test_math.py::test_is_even[-4-True] PASSED                         [ 25%]
# tests/test_math.py::test_is_even[-5-False] PASSED                        [ 31%]
# tests/test_math.py::test_calculate_area[2-3-6] PASSED                    [ 37%]
# tests/test_math.py::test_calculate_area[0-5-0] PASSED                    [ 43%]
# ...
